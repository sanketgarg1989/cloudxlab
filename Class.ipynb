# %%
class LineModel: # y = mx + c
    def fit(self, data):
        x1, y1 = data[0]
        x2, y2 = data[1]
        
        self.m = (y2 - y1) / (x2 - x1)
        self.c = y2 - self.m * x2

    def predict(self, x_new):
         return x_new*self.m + self.c
        return ....

# %%
class Vector:

        def __init__(self, x, y):
            self.x = x
            self.y = y 

        def add(self, other):
            return Vector(self.x + other.x, self.y + other.y)

# %%
Vector.add(3, 4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Vector.add(3, 4)
#
# Cell In[1], line 8, in Vector.add(self, other)
#       7 def add(self, other):
# ----> 8     return Vector(self.x + other.x, self.y + other.y)
#
# AttributeError: 'int' object has no attribute 'x'
